# %% [markdown]
# # Kapitel 08 - Installation Bibliotheken

# %% [markdown]
# ### Installation notwendiger Bibliotheken
# Falls die Bibliotheken noch nicht im entsprechenden Environment installiert wurden, kann das mit einem der beiden nachfolgenden Code-Zellen nachgeholt werden.

# %% [markdown]
# ### ... mit conda

# %%
# Installiere die notwendigen Bibliotheken mit conda
import sys
# !conda update --yes -n base -c  defaults conda
# !conda install --yes --prefix {sys.prefix} tensorflow pillow
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\joachim.steinwendner\AppData\Local\Continuum\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.1|             py_0          11 KB
#     conda-4.8.2                |           py37_0         2.8 MB
#     future-0.18.2              |           py37_0         656 KB
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following packages will be UPDATED:
#
#   backports.functoo~                               1.5-py_2 --> 1.6.1-py_0
#   conda                                       4.7.12-py37_0 --> 4.8.2-py37_0
#   future                                      0.17.1-py37_0 --> 0.18.2-py37_0
#
#
#
# ...
#
# ...

# %% [markdown]
# ## ODER

# %% [markdown]
# ### ... mit pip

# %%
# Installiere die notwendigen Bibliotheken mit pip
import sys
# !{sys.executable} -m pip install tensorflow pillow
